# %% [markdown]
# # Multi Dimensional Dictiory

# %%
## Initializing
dict = {1 : {'name': "Prakash", 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com'},
        2 : {'name': "Ravi", 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com'},
        3 : {'name': "Ram", 'phone-number': 659458520, 'email': 'rk@gmail.com'}

       }
print(dict)
print(len(dict))
print('-'*60)
## Accessing the element
print(dict)
print(dict[1])
print(dict[1]['name'])
print(dict[1]['name'][0])
print('-'*60)

## Updating,  
print(dict)
dict[2]['name'] = 'anjali'
print(dict)

print('-'*60)

## Adding
dict[4] = {'name': "Rohit", 'phone-number': 548758520, 'email': 'rohit@gmail.com'}

print(dict)
print('-'*60)

## deleting
print(dict)
del dict[4]
print(dict)
print('-'*60)


## Iteration through dictionary
print(dict)
for i in dict.keys():
    print(i, dict[i]['name'], dict[i]['email'])


print('-'*60)


## Going a level deeper with marks
data = {1 : {'name': "Prakash", 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com', 'marks': {'hin': 62, 'math': 45, 'sci': 72}},
        2 : {'name': "Ravi"   , 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com', 'marks': {'hin': 45, 'math': 35, 'sci': 42}},
        3 : {'name': "Ram"    , 'phone-number': 659458520 , 'email': 'rk@gmail.com', 'marks': {'hin': 52, 'math': 45, 'sci': 52}}}
print(data)

for i in data.keys():
    print(i, data[i]['name'], data[i]['marks'])
# Out:
# {1: {'name': 'Prakash', 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com'}, 2: {'name': 'Ravi', 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com'}, 3: {'name': 'Ram', 'phone-number': 659458520, 'email': 'rk@gmail.com'}}
# 3
# ------------------------------------------------------------
# {1: {'name': 'Prakash', 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com'}, 2: {'name': 'Ravi', 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com'}, 3: {'name': 'Ram', 'phone-number': 659458520, 'email': 'rk@gmail.com'}}
# {'name': 'Prakash', 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com'}
# Prakash
# P
# ------------------------------------------------------------
# {1: {'name': 'Prakash', 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com'}, 2: {'name': 'Ravi', 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com'}, 3: {'name': 'Ram', 'phone-number': 659458520, 'email': 'rk@gmail.com'}}
# {1: {'name': 'Prakash', 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com'}, 2: {'name': 'anjali', 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com'}, 3: {'name': 'Ram', 'phone-number': 659458520, 'email': 'rk@gmail.com'}}
# ------------------------------------------------------------
# {1: {'name': 'Prakash', 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com'}, 2: {'name': 'anjali', 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com'}, 3: {'name': 'Ram', 'phone-number': 659458520, 'email': 'rk@gmail.com'}, 4: {'name': 'Rohit', 'phone-number': 548758520, 'email': 'rohit@gmail.com'}}
# ------------------------------------------------------------
# {1: {'name': 'Prakash', 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com'}, 2: {'name': 'anjali', 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com'}, 3: {'name': 'Ram', 'phone-number': 659458520, 'email': 'rk@gmail.com'}, 4: {'name': 'Rohit', 'phone-number': 548758520, 'email': 'rohit@gmail.com'}}
# {1: {'name': 'Prakash', 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com'}, 2: {'name': 'anjali', 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com'}, 3: {'name': 'Ram', 'phone-number': 659458520, 'email': 'rk@gmail.com'}}
# ------------------------------------------------------------
# {1: {'name': 'Prakash', 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com'}, 2: {'name': 'anjali', 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com'}, 3: {'name': 'Ram', 'phone-number': 659458520, 'email': 'rk@gmail.com'}}
# 1 Prakash divyaprakash299@gmail.com
# 2 anjali adityakarn334@gmail.com
# 3 Ram rk@gmail.com
# ------------------------------------------------------------
# {1: {'name': 'Prakash', 'phone-number': 9334390221, 'email': 'divyaprakash299@gmail.com', 'marks': {'hin': 62, 'math': 45, 'sci': 72}}, 2: {'name': 'Ravi', 'phone-number': 9834390220, 'email': 'adityakarn334@gmail.com', 'marks': {'hin': 45, 'math': 35, 'sci': 42}}, 3: {'name': 'Ram', 'phone-number': 659458520, 'email': 'rk@gmail.com', 'marks': {'hin': 52, 'math': 45, 'sci': 52}}}
# 1 Prakash {'hin': 62, 'math': 45, 'sci': 72}
# 2 Ravi {'hin': 45, 'math': 35, 'sci': 42}
# 3 Ram {'hin': 52, 'math': 45, 'sci': 52}

# %%
## Problem Statement- Counting Word Frequencies in text corpus

def count_word_frequencies(corpus):
    word_freq = {}  # Multidimensional dictionary to store word frequencies

    for document in corpus:
        words = document.split()

        for word in words:
            if word not in word_freq:
                word_freq[word] = {'total_count': 1, 'documents': {document: 1}}
            else:
                word_freq[word]['total_count'] += 1
                if document in word_freq[word]['documents']:
                    word_freq[word]['documents'][document] += 1
                else:
                    word_freq[word]['documents'][document] = 1
    return word_freq

corpus = [
    "This is the multidimensional dictionary.",
    "This dictionary stores the sub dictionary.",
    "And this is the third containing the word and count.",
    "Is this the first level of dictionary?"
]

word_frequencies = count_word_frequencies(corpus)

# Displaying word frequencies
for word, info in word_frequencies.items():
    print(f"Word: {word}")
    print(f"  Total Count: {info['total_count']}")
    print("  Document Occurrences:")
    for document, count in info['documents'].items():
        print(f"    {document}: {count}")
    print()
# Out:
# Word: This
#   Total Count: 2
#   Document Occurrences:
#     This is the multidimensional dictionary.: 1
#     This dictionary stores the sub dictionary.: 1
#
# Word: is
#   Total Count: 2
#   Document Occurrences:
#     This is the multidimensional dictionary.: 1
#     And this is the third containing the word and count.: 1
#
# Word: the
#   Total Count: 5
#   Document Occurrences:
#     This is the multidimensional dictionary.: 1
#     This dictionary stores the sub dictionary.: 1
#     And this is the third containing the word and count.: 2
#     Is this the first level of dictionary?: 1
#
# Word: multidimensional
#   Total Count: 1
#   Document Occurrences:
#     This is the multidimensional dictionary.: 1
#
# Word: dictionary.
#   Total Count: 2
#   Document Occurrences:
#     This is the multidimensional dictionary.: 1
#     This dictionary stores the sub dictionary.: 1
#
# Word: dictionary
#   Total Count: 1
#   Document Occurrences:
#     This dictionary stores the sub dictionary.: 1
#
# Word: stores
#   Total Count: 1
#   Document Occurrences:
#     This dictionary stores the sub dictionary.: 1
#
# Word: sub
#   Total Count: 1
#   Document Occurrences:
#     This dictionary stores the sub dictionary.: 1
#
# Word: And
#   Total Count: 1
#   Document Occurrences:
#     And this is the third containing the word and count.: 1
#
# Word: this
#   Total Count: 2
#   Document Occurrences:
#     And this is the third containing the word and count.: 1
#     Is this the first level of dictionary?: 1
#
# Word: third
#   Total Count: 1
#   Document Occurrences:
#     And this is the third containing the word and count.: 1
#
# Word: containing
#   Total Count: 1
#   Document Occurrences:
#     And this is the third containing the word and count.: 1
#
# Word: word
#   Total Count: 1
#   Document Occurrences:
#     And this is the third containing the word and count.: 1
#
# Word: and
#   Total Count: 1
#   Document Occurrences:
#     And this is the third containing the word and count.: 1
#
# Word: count.
#   Total Count: 1
#   Document Occurrences:
#     And this is the third containing the word and count.: 1
#
# Word: Is
#   Total Count: 1
#   Document Occurrences:
#     Is this the first level of dictionary?: 1
#
# Word: first
#   Total Count: 1
#   Document Occurrences:
#     Is this the first level of dictionary?: 1
#
# Word: level
#   Total Count: 1
#   Document Occurrences:
#     Is this the first level of dictionary?: 1
#
# Word: of
#   Total Count: 1
#   Document Occurrences:
#     Is this the first level of dictionary?: 1
#
# Word: dictionary?
#   Total Count: 1
#   Document Occurrences:
#     Is this the first level of dictionary?: 1
